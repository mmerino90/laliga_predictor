# %%
import pandas as pd
from pathlib import Path

# Show where we are
print(Path('.').resolve())

# Load and display
df = pd.read_csv("2015-2025.csv")  # notebook is already in data_engineering
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 200)
display(df)
# Out:
# C:\Users\mmeri\laliga_predictor\data_engineering
#            team season  pts  wins  draws  losses  win_rate  draw_rate  \
# 0        Alaves  16/17   55    14     13      11  0.368421   0.342105
# 1        Alaves  17/18   47    15      2      21  0.394737   0.052632
# 2        Alaves  18/19   50    13     11      14  0.342105   0.289474
# 3        Alaves  19/20   39    10      9      19  0.263158   0.236842
# 4        Alaves  20/21   38     9     11      18  0.236842   0.289474
# ..          ...    ...  ...   ...    ...     ...       ...        ...
# 215  Villarreal  21/22   59    16     11      11  0.421053   0.289474
# 216  Villarreal  22/23   64    19      7      12  0.500000   0.184211
# 217  Villarreal  23/24   53    14     11      13  0.368421   0.289474
# 218  Villarreal  24/25   70    20     10       8  0.526316   0.263158
# 219  Villarreal  25/26   20     6      2       2  0.600000   0.200000
#
#      loss_rate  goals_for  goals_against  goal_difference  goals_home  \
# ...
