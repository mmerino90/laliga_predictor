# %%
import pandas as pd

df = pd.read_csv("2015-2025.csv")  # since you're in data_engineering/

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

display(df)
# Out:
#             team season  pts  wins  draws  losses  win_rate  draw_rate  \
# 0         Alaves  16/17   55    14     13      11  0.368421   0.342105
# 1         Alaves  17/18   47    15      2      21  0.394737   0.052632
# 2         Alaves  18/19   50    13     11      14  0.342105   0.289474
# 3         Alaves  19/20   39    10      9      19  0.263158   0.236842
# 4         Alaves  20/21   38     9     11      18  0.236842   0.289474
# 5         Alaves  21/22   31     8      7      23  0.210526   0.184211
# 6         Alaves  23/24   46    12     10      16  0.315789   0.263158
# 7         Alaves  24/25   42    10     12      16  0.263158   0.315789
# 8         Alaves  25/26   12     3      3       4  0.300000   0.300000
# 9        Almeria  22/23   41    11      8      19  0.289474   0.210526
# 10       Almeria  23/24   21     3     12      23  0.078947   0.315789
# 11    Ath Bilbao  15/16   62    18      8      12  0.473684   0.210526
# ...

# %%
import os

os.listdir('/mnt/data')
# Out:
# ['elo_charts',
#  'elo_ranking_25_26.csv',
#  'final_champion_model_25_26.csv',
#  'fixtures_25_26.csv',
#  'montecarlo_25_26.csv',
#  'predictions_25_26.csv',
#  'team_list_25_26.csv']

# %%
Saved Elo charts -> /mnt/data\elo_charts
Saved final champion model -> /mnt/data\final_champion_model_25_26.csv
